# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('esketit2.csv')

# %%
data.head()
# Out:
#    Engagements  NBA_Follower_Count              Created   Type  \
# 0       502093            36984682  2019-05-22 03:30:51  Video
# 1       603380            36984682  2019-05-22 02:53:33  Video
# 2       603380            36984682  2019-05-22 02:19:58  Video
# 3       725100            36984682  2019-05-22 02:02:41  Video
# 4       661446            36984682  2019-05-22 00:47:49  Video
#
#                                          Description  Len_Desc  Tagged_Count  \
# 0  The @raptors bench trio of @sergeibaka @norman...        95             4
# 1  @kyle_lowry7 pulls from deep for the @raptors ...        64             2
# 2     @k_mid22 with some english on the @bucks dime!        46             2
# 3        Kawhi punches it home with the left on TNT!        43             0
# 4  @giannis_an34 goes baseline early to rock the ...        57             1
#
#    DayOfWeek  playOffDate  month      ...        teamTagged otherTagged  \
# 0  Wednesday            1      5      ...                 0           1
# 1  Wednesday            1      5      ...                 0           1
# 2  Wednesday            1      5      ...                 0           1
# 3  Wednesday            1      5      ...                 0           0
# 4  Wednesday            1      5      ...                 0           1
#
#    top3Tagged bottom3Tagged hashtags  hasHashtag  HashLevel  sqrEngagements  \
# 0           0             0       []       False       None    252097380649
# 1           0             0       []       False       None    364067424400
# 2           0             0       []       False       None    364067424400
# 3           0             0       []       False       None    525770010000
# 4           0             0       []       False       None    437510810916
#
#    monthDateYear postsInThatDay
# 0     2019-05-22              5
# 1     2019-05-22              5
# 2     2019-05-22              5
# 3     2019-05-22              5
# 4     2019-05-22              5
#
# [5 rows x 25 columns]

# %%
data.corr()
# Out:
#                     Engagements  NBA_Follower_Count  Len_Desc  Tagged_Count  \
# Engagements            1.000000           -0.053031 -0.274011     -0.152747
# NBA_Follower_Count    -0.053031            1.000000  0.106531      0.073120
# Len_Desc              -0.274011            0.106531  1.000000      0.499513
# Tagged_Count          -0.152747            0.073120  0.499513      1.000000
# playOffDate           -0.069574            0.462356  0.119469      0.100513
# month                  0.020518           -0.191020 -0.005735      0.001834
# hour                  -0.161807           -0.013677  0.291998      0.085107
# propOfSpecialTexts     0.050351            0.013238 -0.210193      0.234276
# teamTagged                  NaN                 NaN       NaN           NaN
# otherTagged            0.087058            0.072906  0.308612      0.663593
# top3Tagged                  NaN                 NaN       NaN           NaN
# bottom3Tagged               NaN                 NaN       NaN           NaN
# hasHashtag            -0.151141            0.049196  0.347956      0.010400
# sqrEngagements         0.986614           -0.058524 -0.268426     -0.167695
# postsInThatDay         0.069409            0.131017 -0.066482     -0.022981
#
#                     playOffDate     month      hour  propOfSpecialTexts  \
# Engagements           -0.069574  0.020518 -0.161807            0.050351
# NBA_Follower_Count     0.462356 -0.191020 -0.013677            0.013238
# Len_Desc               0.119469 -0.005735  0.291998           -0.210193
# Tagged_Count           0.100513  0.001834  0.085107            0.234276
# playOffDate            1.000000 -0.110677  0.021008            0.020415
# month                 -0.110677  1.000000 -0.014950            0.015693
# hour                   0.021008 -0.014950  1.000000           -0.016571
# propOfSpecialTexts     0.020415  0.015693 -0.016571            1.000000
# teamTagged                  NaN       NaN       NaN                 NaN
# otherTagged            0.072440 -0.030702 -0.048713            0.190806
# top3Tagged                  NaN       NaN       NaN                 NaN
# bottom3Tagged               NaN       NaN       NaN                 NaN
# hasHashtag             0.146008  0.049643  0.231509            0.165148
# sqrEngagements        -0.078575  0.019601 -0.163222            0.053808
# postsInThatDay         0.027860 -0.207047 -0.089082            0.076334
#
#                     teamTagged  otherTagged  top3Tagged  bottom3Tagged  \
# Engagements                NaN     0.087058         NaN            NaN
# NBA_Follower_Count         NaN     0.072906         NaN            NaN
# Len_Desc                   NaN     0.308612         NaN            NaN
# Tagged_Count               NaN     0.663593         NaN            NaN
# playOffDate                NaN     0.072440         NaN            NaN
# month                      NaN    -0.030702         NaN            NaN
# hour                       NaN    -0.048713         NaN            NaN
# propOfSpecialTexts         NaN     0.190806         NaN            NaN
# teamTagged                 NaN          NaN         NaN            NaN
# otherTagged                NaN     1.000000         NaN            NaN
# top3Tagged                 NaN          NaN         NaN            NaN
# bottom3Tagged              NaN          NaN         NaN            NaN
# hasHashtag                 NaN    -0.031240         NaN            NaN
# sqrEngagements             NaN     0.070767         NaN            NaN
# postsInThatDay             NaN     0.030132         NaN            NaN
#
#                     hasHashtag  sqrEngagements  postsInThatDay
# Engagements          -0.151141        0.986614        0.069409
# NBA_Follower_Count    0.049196       -0.058524        0.131017
# Len_Desc              0.347956       -0.268426       -0.066482
# Tagged_Count          0.010400       -0.167695       -0.022981
# playOffDate           0.146008       -0.078575        0.027860
# month                 0.049643        0.019601       -0.207047
# hour                  0.231509       -0.163222       -0.089082
# propOfSpecialTexts    0.165148        0.053808        0.076334
# teamTagged                 NaN             NaN             NaN
# otherTagged          -0.031240        0.070767        0.030132
# top3Tagged                 NaN             NaN             NaN
# bottom3Tagged              NaN             NaN             NaN
# hasHashtag            1.000000       -0.132080        0.053455
# sqrEngagements       -0.132080        1.000000        0.069676
# postsInThatDay        0.053455        0.069676        1.000000

# %%
data.shape
# Out:
# (7766, 25)

# %%
data[['monthDateYear']]
# Out:
#      monthDateYear
# 0       2019-05-22
# 1       2019-05-22
# 2       2019-05-22
# 3       2019-05-22
# 4       2019-05-22
# 5       2019-05-21
# 6       2019-05-21
# 7       2019-05-21
# 8       2019-05-21
# 9       2019-05-21
# 10      2019-05-21
# 11      2019-05-21
# 12      2019-05-21
# 13      2019-05-21
# 14      2019-05-21
# 15      2019-05-21
# 16      2019-05-21
# 17      2019-05-21
# 18      2019-05-21
# 19      2019-05-21
# 20      2019-05-21
# 21      2019-05-21
# 22      2019-05-21
# 23      2019-05-21
# 24      2019-05-20
# 25      2019-05-20
# 26      2019-05-20
# 27      2019-05-20
# 28      2019-05-20
# 29      2019-05-20
# ...            ...
# 7736    2017-10-04
# 7737    2017-10-04
# 7738    2017-10-04
# 7739    2017-10-04
# 7740    2017-10-04
# 7741    2017-10-03
# 7742    2017-10-03
# 7743    2017-10-03
# 7744    2017-10-03
# 7745    2017-10-03
# 7746    2017-10-03
# 7747    2017-10-03
# 7748    2017-10-03
# 7749    2017-10-03
# 7750    2017-10-03
# 7751    2017-10-03
# 7752    2017-10-03
# 7753    2017-10-03
# 7754    2017-10-03
# 7755    2017-10-02
# 7756    2017-10-02
# 7757    2017-10-02
# 7758    2017-10-02
# 7759    2017-10-02
# 7760    2017-10-02
# 7761    2017-10-01
# 7762    2017-10-01
# 7763    2017-10-01
# 7764    2017-10-01
# 7765    2017-10-01
#
# [7766 rows x 1 columns]

# %%
def seasonTime(date): 
    if pd.Timestamp('2019-6-14') > date >= pd.Timestamp('2019-4-13'): 
        return 'Playoffs' 
    elif pd.Timestamp('2019-4-13')> date > pd.Timestamp('2019-2-17'):
        return 'PostAllStarBreak'
    elif pd.Timestamp('2019-2-17')>= date >= pd.Timestamp('2019-2-15'):
        return 'AllStarBreak'
    elif pd.Timestamp('2019-2-15')> date >= pd.Timestamp('2018-10-16'):
        return 'BeforeAllStarBreak'
    elif pd.Timestamp('2018-6-8') > date >= pd.Timestamp('2018-4-14'): 
        return 'Playoffs' 
    elif pd.Timestamp('2018-4-14')> date > pd.Timestamp('2018-2-18'):
        return 'PostAllStarBreak'
    elif pd.Timestamp('2018-2-18')>= date >= pd.Timestamp('2018-2-16'):
        return 'AllStarBreak'
    elif pd.Timestamp('2018-2-16')> date >= pd.Timestamp('2017-10-17'):
        return 'BeforeAllStarBreak'
    elif pd.Timestamp('2017-6-12') > date >= pd.Timestamp('2017-4-15'): 
        return 'Playoffs' 
    elif pd.Timestamp('2017-4-15')> date > pd.Timestamp('2017-2-19'):
        return 'PostAllStarBreak'
    elif pd.Timestamp('2017-2-19')>= date >= pd.Timestamp('2017-2-17'):
        return 'AllStarBreak'
    elif pd.Timestamp('2017-2-17')> date >= pd.Timestamp('2016-10-25'):
        return 'BeforeAllStarBreak'
    else: return 'Offseason'

# %%
data['Created']= pd.to_datetime(data['Created'])
data['SeasonTime'] = data.Created.map(lambda a: seasonTime(a))

# %%
data.head()
# Out:
#    Engagements  NBA_Follower_Count             Created   Type  \
# 0       502093            36984682 2019-05-22 03:30:51  Video
# 1       603380            36984682 2019-05-22 02:53:33  Video
# 2       603380            36984682 2019-05-22 02:19:58  Video
# 3       725100            36984682 2019-05-22 02:02:41  Video
# 4       661446            36984682 2019-05-22 00:47:49  Video
#
#                                          Description  Len_Desc  Tagged_Count  \
# 0  The @raptors bench trio of @sergeibaka @norman...        95             4
# 1  @kyle_lowry7 pulls from deep for the @raptors ...        64             2
# 2     @k_mid22 with some english on the @bucks dime!        46             2
# 3        Kawhi punches it home with the left on TNT!        43             0
# 4  @giannis_an34 goes baseline early to rock the ...        57             1
#
#    DayOfWeek  playOffDate  month    ...      otherTagged top3Tagged  \
# 0  Wednesday            1      5    ...                1          0
# 1  Wednesday            1      5    ...                1          0
# 2  Wednesday            1      5    ...                1          0
# 3  Wednesday            1      5    ...                0          0
# 4  Wednesday            1      5    ...                1          0
#
#    bottom3Tagged hashtags hasHashtag  HashLevel  sqrEngagements  \
# 0              0       []      False       None    252097380649
# 1              0       []      False       None    364067424400
# 2              0       []      False       None    364067424400
# 3              0       []      False       None    525770010000
# 4              0       []      False       None    437510810916
#
#    monthDateYear  postsInThatDay SeasonTime
# 0     2019-05-22               5   Playoffs
# 1     2019-05-22               5   Playoffs
# 2     2019-05-22               5   Playoffs
# 3     2019-05-22               5   Playoffs
# 4     2019-05-22               5   Playoffs
#
# [5 rows x 26 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')
import datetime

# %%
data.groupby('SeasonTime').count()
# Out:
#                     Engagements  NBA_Follower_Count  Created  Type  \
# SeasonTime
# AllStarBreak                 97                  97       97    97
# BeforeAllStarBreak         3573                3573     3573  3573
# Offseason                  1049                1049     1049  1049
# Playoffs                   1396                1396     1396  1396
# PostAllStarBreak           1651                1651     1651  1651
#
#                     Description  Len_Desc  Tagged_Count  DayOfWeek  \
# SeasonTime
# AllStarBreak                 97        97            97         97
# BeforeAllStarBreak         3566      3573          3573       3573
# Offseason                  1048      1049          1049       1049
# Playoffs                   1395      1396          1396       1396
# PostAllStarBreak           1646      1651          1651       1651
#
#                     playOffDate  month       ...        teamTagged  \
# SeasonTime                                   ...
# AllStarBreak                 97     97       ...                97
# BeforeAllStarBreak         3573   3573       ...              3573
# Offseason                  1049   1049       ...              1049
# Playoffs                   1396   1396       ...              1396
# PostAllStarBreak           1651   1651       ...              1651
#
#                     otherTagged  top3Tagged  bottom3Tagged  hashtags  \
# SeasonTime
# AllStarBreak                 97          97             97        97
# BeforeAllStarBreak         3573        3573           3573      3573
# Offseason                  1049        1049           1049      1049
# Playoffs                   1396        1396           1396      1396
# PostAllStarBreak           1651        1651           1651      1651
#
#                     hasHashtag  HashLevel  sqrEngagements  monthDateYear  \
# SeasonTime
# AllStarBreak                97         97              97             97
# BeforeAllStarBreak        3573       3573            3573           3573
# Offseason                 1049       1049            1049           1049
# Playoffs                  1396       1396            1396           1396
# PostAllStarBreak          1651       1651            1651           1651
#
#                     postsInThatDay
# SeasonTime
# AllStarBreak                    97
# BeforeAllStarBreak            3573
# Offseason                     1049
# Playoffs                      1396
# PostAllStarBreak              1651
#
# [5 rows x 25 columns]

# %%
plt.figure(figsize=(12, 9))
sns.boxplot(x = 'SeasonTime', y = 'Engagements', data = data[data['Type'] == 'Video'])

# %%
plt.figure(figsize=(12, 9))

sns.boxplot(x = 'SeasonTime', y = 'Engagements', data = data[data['Type'] == 'Album'])

# %%
plt.figure(figsize=(12, 9))
sns.boxplot(x = 'SeasonTime', y = 'Engagements', data = data[data['Type'] == 'Photo'])

# %%
data[data['Type'] == 'Photo'].describe()
# Out:
#          Engagements  NBA_Follower_Count     Len_Desc  Tagged_Count  \
# count    1595.000000        1.595000e+03  1595.000000   1595.000000
# mean   357547.363636        3.055114e+07    79.284639      1.376176
# std     62948.954886        3.817776e+06    46.444357      1.093581
# min    127816.000000        2.487554e+07     0.000000      0.000000
# 25%    317654.500000        2.732043e+07    46.500000      0.000000
# 50%    352718.000000        2.950614e+07    80.000000      2.000000
# 75%    395260.000000        3.449247e+07   105.000000      2.000000
# max    616356.000000        3.695516e+07   639.000000     10.000000
#
#        playOffDate        month         hour  propOfSpecialTexts  teamTagged  \
# count  1595.000000  1595.000000  1595.000000         1595.000000      1595.0
# mean      0.115987     5.606897     7.958621            0.267203         0.0
# std       0.320310     3.491568     7.517577            0.221071         0.0
# min       0.000000     1.000000     0.000000            0.000000         0.0
# 25%       0.000000     3.000000     2.000000            0.145503         0.0
# 50%       0.000000     5.000000     4.000000            0.214286         0.0
# 75%       0.000000     9.000000    15.000000            0.300000         0.0
# max       1.000000    12.000000    23.000000            1.000000         0.0
#
#        otherTagged  top3Tagged  bottom3Tagged  sqrEngagements  postsInThatDay
# count  1595.000000      1595.0         1595.0    1.595000e+03     1595.000000
# mean      0.732915         0.0            0.0    1.318002e+11       17.354232
# std       0.442576         0.0            0.0    4.639240e+10        7.570947
# min       0.000000         0.0            0.0    1.633693e+10        1.000000
# 25%       0.000000         0.0            0.0    1.009044e+11       12.000000
# 50%       1.000000         0.0            0.0    1.244100e+11       16.000000
# 75%       1.000000         0.0            0.0    1.562305e+11       21.000000
# max       1.000000         0.0            0.0    3.798947e+11       42.000000

# %%
data[data['Type'] == 'Album'].describe()
# Out:
#          Engagements  NBA_Follower_Count    Len_Desc  Tagged_Count  \
# count     713.000000        7.130000e+02  713.000000    713.000000
# mean   348465.339411        3.081558e+07   72.478261      1.234222
# std     64001.672190        3.616505e+06   35.801221      1.711611
# min    170607.000000        2.487554e+07    8.000000      0.000000
# 25%    300650.000000        2.712987e+07   47.000000      0.000000
# 50%    348534.000000        3.109777e+07   67.000000      0.000000
# 75%    403710.000000        3.412678e+07   89.000000      2.000000
# max    470730.000000        3.689974e+07  388.000000      7.000000
#
#        playOffDate       month        hour  propOfSpecialTexts  teamTagged  \
# count   713.000000  713.000000  713.000000          713.000000       713.0
# mean      0.039271    6.123422    9.370266            0.186628         0.0
# std       0.194375    4.073610    6.466666            0.181421         0.0
# min       0.000000    1.000000    0.000000            0.000000         0.0
# 25%       0.000000    2.000000    5.000000            0.000000         0.0
# 50%       0.000000    5.000000    6.000000            0.153846         0.0
# 75%       0.000000   10.000000   16.000000            0.333333         0.0
# max       1.000000   12.000000   23.000000            1.000000         0.0
#
#        otherTagged  top3Tagged  bottom3Tagged  sqrEngagements  postsInThatDay
# count   713.000000       713.0          713.0    7.130000e+02      713.000000
# mean      0.465638         0.0            0.0    1.255186e+11       14.712482
# std       0.499168         0.0            0.0    4.413046e+10        7.060738
# min       0.000000         0.0            0.0    2.910675e+10        2.000000
# 25%       0.000000         0.0            0.0    9.039042e+10       10.000000
# 50%       0.000000         0.0            0.0    1.214759e+11       14.000000
# 75%       1.000000         0.0            0.0    1.629818e+11       19.000000
# max       1.000000         0.0            0.0    2.215867e+11       42.000000

# %%
data[data['Type'] == 'Video'].describe()
# Out:
#         Engagements  NBA_Follower_Count     Len_Desc  Tagged_Count  \
# count  5.458000e+03        5.458000e+03  5458.000000   5458.000000
# mean   6.927736e+05        3.034095e+07    65.616893      1.583730
# std    1.003232e+05        3.742107e+06    33.494386      1.022761
# min    2.900720e+05        2.487554e+07     0.000000      0.000000
# 25%    6.323550e+05        2.687360e+07    43.000000      1.000000
# 50%    6.849445e+05        2.989584e+07    59.000000      2.000000
# 75%    7.446290e+05        3.375725e+07    82.000000      2.000000
# max    1.129585e+06        3.698468e+07   348.000000      8.000000
#
#        playOffDate        month         hour  propOfSpecialTexts  teamTagged  \
# count  5458.000000  5458.000000  5458.000000         5458.000000      5458.0
# mean      0.070722     6.087395     7.812019            0.275958         0.0
# std       0.256383     3.994483     8.254065            0.167308         0.0
# min       0.000000     1.000000     0.000000            0.000000         0.0
# 25%       0.000000     3.000000     2.000000            0.166667         0.0
# 50%       0.000000     5.000000     3.000000            0.250000         0.0
# 75%       0.000000    10.000000    17.000000            0.333333         0.0
# max       1.000000    12.000000    23.000000            1.000000         0.0
#
#        otherTagged  top3Tagged  bottom3Tagged  sqrEngagements  postsInThatDay
# count  5458.000000      5458.0         5458.0    5.458000e+03     5458.000000
# mean      0.868450         0.0            0.0    4.899981e+11       16.572737
# std       0.338032         0.0            0.0    1.437499e+11        6.772212
# min       0.000000         0.0            0.0    8.414177e+10        1.000000
# 25%       1.000000         0.0            0.0    3.998728e+11       12.000000
# 50%       1.000000         0.0            0.0    4.691490e+11       16.000000
# 75%       1.000000         0.0            0.0    5.544723e+11       20.000000
# max       1.000000         0.0            0.0    1.275962e+12       42.000000

# %% [markdown]
# **Features We Are Pursuing**
# - Video and allStarbreak
